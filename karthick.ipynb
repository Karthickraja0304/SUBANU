# %%
a=23.5

# %%
b=22

# %%
c="spring"

# %%
d= 56+2j

# %%
type(a)
# Out:
# float

# %%
type(b)
# Out:
# int

# %%
type(c)
# Out:
# str

# %%
type(d)
# Out:
# complex

# %%
e= True

# %%
type(e)
# Out:
# bool

# %%
A=23.502321316113211

# %%
A
# Out:
# 23.50232131611321

# %%
a
# Out:
# 23.5

# %%
a+A
# Out:
# 47.00232131611321

# %%
d.real
# Out:
# 56.0

# %%
d.imag
# Out:
# 2.0

# %%
d.conjugate
# Out:
# <function complex.conjugate>

# %%
a=input()
# Out:
# 56+52j

# %%
a
# Out:
# '56+52j'

# %%
a.real
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10484/3920258732.py in <module>
# ----> 1 a.real
#
# AttributeError: 'str' object has no attribute 'real'

# %%
b=complex(a)

# %%
b
# Out:
# (56+52j)

# %%
b.real
# Out:
# 56.0
