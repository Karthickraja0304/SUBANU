# %%
1+1
# Out:
# 2

# %%
sdsfvsdgv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11552/1020758895.py in <module>
# ----> 1 sdsfvsdgv
#
# NameError: name 'sdsfvsdgv' is not defined

# %%
3*5
# Out:
# 15

# %%
"karthick raja"
# Out:
# 'karthick raja'

# %%
'karthick raja'
# Out:
# 'karthick raja'
